# %%
import sys
import numpy as np
sys.path.append('..\\..\\..\\') # to pick up network_generator.py
import multiple_regression_random_initialisation as mregress
# Jupyter Notebook will carry over previous variable values, so reset for this next run
if "all_regression_out_parameters" in locals():
     del all_regression_out_parameters 
if "regression_parameters" in locals():
    del regression_parameters

# not a random initialisation
input_csv = "ExampleOne_Chain_U1XU2BU3Y_NetworkValues_deleted_U1U2U3.csv"
counter = 0 
while counter < 1:
    regression_parameters = mregress.multi_regress_from_csv_2(input_csv, \
        threshold=0.0001, random = 0, max_iter = 1000000, learning_rate = 0.0005)

    if "all_regression_out_parameters" in locals():
        all_regression_out_parameters = np.append(all_regression_out_parameters, regression_parameters, axis=0)
    else:
        all_regression_out_parameters = regression_parameters
    #print("regression_parameters: \n", regression_parameters)
    #print("all_regression_parameters: \n", all_regression_out_parameters)
    counter += 1
print("all_regression_parameters: \n", all_regression_out_parameters)
# Out:
# Calling Regression with threshold = 0.0001, random =             0, max_iter = 1000000
# random,  0
# setting initial parameters using gradient estimates.
# Calling Regression with threshold = 0.0001, random =             0, max_iter = 1000000
# random,  0
# setting initial parameters using gradient estimates.
# Calling Regression with threshold = 0.0001, random =             0, max_iter = 1000000
# random,  0
# setting initial parameters using gradient estimates.
# all_regression_parameters:
#  [['  ' '  ']
#  ['dependent' 'X']
#  ['intercept' '3.8259338762973076']
#  ['B' '0.5469823413512638']
#  ['Y' '0.15334543428085137']
#  ['r_squared ' array([0.34701986])]
#  ['  ' '  ']
#  ['dependent' 'B']
#  ['intercept' '4.385456391208145']
#  ['X' '0.3896168148684927']
#  ['Y' '0.3704232895567538']
#  ['r_squared ' array([0.44602927])]
#  ['  ' '  ']
#  ['dependent' 'Y']
#  ['intercept' '6.696124453759929']
#  ['X' '0.13464631086560516']
#  ['B' '0.45662271169049645']
#  ['r_squared ' array([0.31053248])]]

# %% [markdown]
# # three random initialisations - small max_iter - may not converge will then repeat with higher iteration number to see how much further it optimises.

# %%
import sys
import numpy as np
sys.path.append('..\\..\\..\\') # to pick up network_generator.py
import multiple_regression_random_initialisation as mregress
# Jupyter Notebook will carry over previous variable values, so reset for this next run
if "all_regression_out_parameters" in locals():
     del all_regression_out_parameters 
if "regression_parameters" in locals():
    del regression_parameters

# three random initialisations - small max_iter - may not converge
input_csv = "ExampleOne_Chain_U1XU2BU3Y_NetworkValues_deleted_U1U2U3.csv"
counter = 0 
while counter < 3:
    regression_parameters = mregress.multi_regress_from_csv_2(input_csv, \
        threshold=0.0001, random = 1, max_iter = 100000, learning_rate = 0.0005)

    if "all_regression_out_parameters" in locals():
        all_regression_out_parameters = np.append(all_regression_out_parameters, regression_parameters, axis=0)
    else:
        all_regression_out_parameters = regression_parameters
    #print("regression_parameters: \n", regression_parameters)
    #print("all_regression_parameters: \n", all_regression_out_parameters)
    counter += 1
print("all_regression_parameters: \n", all_regression_out_parameters)
# Out:
# Calling Regression with threshold = 0.0001, random =             1, max_iter = 100000
# random,  1
# using pseudo random initial parameter values.
# Calling Regression with threshold = 0.0001, random =             1, max_iter = 100000
# random,  1
# using pseudo random initial parameter values.
# Calling Regression with threshold = 0.0001, random =             1, max_iter = 100000
# random,  1
# using pseudo random initial parameter values.
# Calling Regression with threshold = 0.0001, random =             1, max_iter = 100000
# random,  1
# using pseudo random initial parameter values.
# Calling Regression with threshold = 0.0001, random =             1, max_iter = 100000
# random,  1
# using pseudo random initial parameter values.
# Calling Regression with threshold = 0.0001, random =             1, max_iter = 100000
# random,  1
# using pseudo random initial parameter values.
# Calling Regression with threshold = 0.0001, random =             1, max_iter = 100000
# random,  1
# using pseudo random initial parameter values.
# Calling Regression with threshold = 0.0001, random =             1, max_iter = 100000
# random,  1
# using pseudo random initial parameter values.
# Calling Regression with threshold = 0.0001, random =             1, max_iter = 100000
# random,  1
# using pseudo random initial parameter values.
# all_regression_parameters:
#  [['  ' '  ']
#  ['dependent' 'X']
#  ['intercept' '3.352755786159781']
#  ['B' '0.5604720856898953']
#  ['Y' '0.1667753971153004']
#  ['r_squared ' array([0.34651467])]
#  ['  ' '  ']
#  ['dependent' 'B']
#  ['intercept' '3.8180528286523985']
#  ['X' '0.40235303648999465']
#  ['Y' '0.39072994913932824']
#  ['r_squared ' array([0.44512548])]
#  ['  ' '  ']
#  ['dependent' 'Y']
#  ['intercept' '5.922989344318169']
#  ['X' '0.14943564078246094']
#  ['B' '0.4861275223416721']
#  ['r_squared ' array([0.30867712])]
#  ['  ' '  ']
#  ['dependent' 'X']
#  ['intercept' '3.3468146083857953']
#  ['B' '0.5606414615991185']
#  ['Y' '0.16694402241380946']
#  ['r_squared ' array([0.3465019])]
#  ['  ' '  ']
#  ['dependent' 'B']
#  ['intercept' '3.8951587326183867']
#  ['X' '0.40062227914893467']
#  ['Y' '0.3879704258529542']
#  ['r_squared ' array([0.44535443])]
#  ['  ' '  ']
#  ['dependent' 'Y']
#  ['intercept' '5.942600553119307']
#  ['X' '0.14906049724870293']
#  ['B' '0.4853791085194929']
#  ['r_squared ' array([0.30877005])]
#  ['  ' '  ']
#  ['dependent' 'X']
#  ['intercept' '3.2699660830436046']
#  ['B' '0.5628323216183676']
#  ['Y' '0.16912517336043892']
#  ['r_squared ' array([0.34632243])]
#  ['  ' '  ']
#  ['dependent' 'B']
#  ['intercept' '3.81040898137172']
#  ['X' '0.40252461407503665']
#  ['Y' '0.3910035128158248']
#  ['r_squared ' array([0.44510097])]
#  ['  ' '  ']
#  ['dependent' 'Y']
#  ['intercept' '6.007986196300812']
#  ['X' '0.14780973287773114']
#  ['B' '0.48288382535641355']
#  ['r_squared ' array([0.30906264])]]

# %% [markdown]
# tenfold more iterations than the previous optimisations.

# %%
import sys
import numpy as np
sys.path.append('..\\..\\..\\') # to pick up network_generator.py
import multiple_regression_random_initialisation as mregress
# Jupyter Notebook will carry over previous variable values, so reset for this next run
if "all_regression_out_parameters" in locals():
     del all_regression_out_parameters 
if "regression_parameters" in locals():
    del regression_parameters

input_csv = "ExampleOne_Chain_U1XU2BU3Y_NetworkValues_deleted_U1U2U3.csv"
counter = 0 
while counter < 2:
    regression_parameters = mregress.multi_regress_from_csv_2(input_csv, \
        threshold=0.0001, random = 1, max_iter = 1000000, learning_rate = 0.0005)

    if "all_regression_out_parameters" in locals():
        all_regression_out_parameters = np.append(all_regression_out_parameters, regression_parameters, axis=0)
    else:
        all_regression_out_parameters = regression_parameters
    #print("regression_parameters: \n", regression_parameters)
    #print("all_regression_parameters: \n", all_regression_out_parameters)
    counter += 1
print("all_regression_parameters: \n", all_regression_out_parameters)
# Out:
# Calling Regression with threshold = 0.0001, random =             1, max_iter = 1000000
# random,  1
# using pseudo random initial parameter values.
# <__array_function__ internals>:5: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Calling Regression with threshold = 0.0001, random =             1, max_iter = 1000000
# random,  1
# using pseudo random initial parameter values.
# Calling Regression with threshold = 0.0001, random =             1, max_iter = 1000000
# random,  1
# using pseudo random initial parameter values.
# Calling Regression with threshold = 0.0001, random =             1, max_iter = 1000000
# random,  1
# using pseudo random initial parameter values.
# Calling Regression with threshold = 0.0001, random =             1, max_iter = 1000000
# random,  1
# using pseudo random initial parameter values.
# Calling Regression with threshold = 0.0001, random =             1, max_iter = 1000000
# random,  1
# using pseudo random initial parameter values.
# all_regression_parameters:
#  [['  ' '  ']
#  ['dependent' 'X']
#  ['intercept' '3.825933879064905']
#  ['B' '0.5469823412723629']
#  ['Y' '0.15334543420230048']
#  ['r_squared ' array([0.34701986])]
#  ['  ' '  ']
#  ['dependent' 'B']
#  ['intercept' '4.385456393662034']
#  ['X' '0.3896168148134118']
#  ['Y' '0.3704232894689321']
#  ['r_squared ' array([0.44602927])]
#  ['  ' '  ']
#  ['dependent' 'Y']
#  ['intercept' '6.696124453883637']
#  ['X' '0.13464631086323606']
#  ['B' '0.45662271168577845']
#  ['r_squared ' array([0.31053248])]
#  ['  ' '  ']
#  ['dependent' 'X']
#  ['intercept' '3.8259338824528335']
#  ['B' '0.5469823411757788']
#  ['Y' '0.15334543410614127']
#  ['r_squared ' array([0.34701986])]
#  ['  ' '  ']
#  ['dependent' 'B']
#  ['intercept' '4.385456391779436']
#  ['X' '0.38961681485566957']
#  ['Y' '0.3704232895363075']
#  ['r_squared ' array([0.44602927])]
#  ['  ' '  ']
#  ['dependent' 'Y']
#  ['intercept' '6.696124454140279']
#  ['X' '0.13464631085832715']
#  ['B' '0.4566227116759838']
#  ['r_squared ' array([0.31053248])]]
