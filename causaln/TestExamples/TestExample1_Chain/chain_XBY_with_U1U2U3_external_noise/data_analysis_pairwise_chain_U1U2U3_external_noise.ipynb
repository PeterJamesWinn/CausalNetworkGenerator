# %% [markdown]
# Scripts to analyse 1. Noise free data generated for X ->B -> Y 2.

# %%
from sys import *
sys.path.append('..\\..\\') 
sys.path.append('..\\..\\..\\') # to pick up network_generator.py
import calculate_write_pairwise_regression as pair_regress
filename = "ExampleOne_Chain_U1XU2BU3Y_NetworkValues.csv"

slope_dataframe, intercept_dataframe, correlation_dataframe, p_dataframe, std_err_dataframe = pair_regress.regress_from_csv(filename)
dictionary_dataframes = dict(zip(["slope", "intercept", "correlation", "p-value", "std_err"],
    [slope_dataframe, intercept_dataframe, correlation_dataframe, 
    p_dataframe, std_err_dataframe]))
for name in ["slope",  "intercept", "correlation"]:
    pair_regress.dataframe_to_html(dictionary_dataframes[name], name)
    pair_regress.dataframe_to_tex(dictionary_dataframes[name], name)
    pair_regress.dataframe_to_csv(dictionary_dataframes[name], name)
# Out:
# calculation_key, slope, intercept, r_value, p_value, std_err
# XX 1.0 0.0 1.0 0.0 0.0
# BX 0.6300114444718714 4.9550631689967 0.5772809292521005 3.6270903051706437e-19 0.06332994046329206
# YX 0.4523656700135652 7.91054523160521 0.41251954013491676 1.2805602588948233e-09 0.0709915182295867
# U1X 0.9068772552625005 8.22983881682087 0.6830247004050496 7.955159655091849e-29 0.06891876090027853
# U2X 0.05166153842017753 14.841947846472532 0.0386822491460561 0.5865623985064539 0.09484137845873285
# U3X 0.1903289433132665 13.709755295761338 0.14580805610310263 0.03938561132396126 0.09177499987386192
# calculation_key, slope, intercept, r_value, p_value, std_err
# XB 0.5289638374070006 8.26359111791731 0.5772809292521005 3.6270903051706437e-19 0.05317244412647413
# BB 1.0 0.0 1.0 0.0 0.0
# YB 0.5466725603847447 7.467537840366173 0.5440557311902172 8.361674688859499e-17 0.059915426778803946
# U1B 0.42316563126092765 13.053929670353028 0.3478239763027435 4.4971810932049683e-07 0.08106199357886325
# U2B 1.0258307692100896 8.420973923236257 0.8382649979947991 4.7507837278389834e-54 0.0474206892293663
# U3B 0.05930122660311066 15.84821813811099 0.049579436700396516 0.4856819291146015 0.08489753134414334
# calculation_key, slope, intercept, r_value, p_value, std_err
# XY 0.37618321255019244 10.469467840735067 0.41251954013491676 1.2805602588948233e-09 0.05903590648384225
# BY 0.5414514283149703 7.363305432758111 0.5440557311902172 8.361674688859499e-17 0.05934318961363716
# YY 1.0 0.0 1.0 0.0 0.0
# U1Y 0.3511261033846874 13.488295220836367 0.28999875312301826 3.108624368067593e-05 0.08234904976647392
# U2Y 0.47537366299288 12.53974592663986 0.3903234232076062 1.1056273661017679e-08 0.07968665239949162
# U3Y 1.0296506133015542 7.924109069055506 0.8649911818995113 3.2974072406858795e-61 0.04244876567207169
# calculation_key, slope, intercept, r_value, p_value, std_err
# XU1 0.5144276567266761 -0.10987748851454349 0.6830247004050496 7.955159655091849e-29 0.039094283673675415
# BU1 0.28589637142921276 3.0627417364181024 0.3478239763027435 4.4971810932049683e-07 0.054766569194096566
# YU1 0.23951302965580903 3.8492901370017543 0.28999875312301826 3.108624368067593e-05 0.05617261208642261
# U1U1 1.0 0.0 1.0 0.0 0.0
# U2U1 -0.03062967876879066 7.9660016749135325 -0.030450815328850387 0.6686223053468053 0.0714511919126494
# U3U1 0.13487497688561972 6.645605185839618 0.1371892769512045 0.05272608692202362 0.06920743696641231
# calculation_key, slope, intercept, r_value, p_value, std_err
# XU2 0.02896383740700101 7.263591117917304 0.0386822491460561 0.5865623985064539 0.05317244412647413
# BU2 0.684994277764065 -3.47753158449836 0.8382649979947991 4.7507837278389834e-54 0.03166497023164594
# YU2 0.32048972537796216 2.512265224563568 0.3903234232076062 1.1056273661017679e-08 0.05372353441504123
# U1U2 -0.030272996370322696 7.939010261942594 -0.030450815328850387 0.6686223053468053 0.0706191432745564
# U2U2 1.0 0.0 1.0 0.0 0.0
# U3U2 -0.03586324505352259 7.993340490230322 -0.0366928870751293 0.6059682880974744 0.06941327688748311
# calculation_key, slope, intercept, r_value, p_value, std_err
# XU3 0.11170129384669181 6.337672281776416 0.14580805610310263 0.03938561132396126 0.053861415138618085
# BU3 0.04145142831496986 7.363305432758116 0.049579436700396516 0.4856819291146015 0.059343189613637236
# YU3 0.7266637198076284 -3.733768920183101 0.8649911818995113 3.2974072406858795e-61 0.029957713389402025
# U1U3 0.13954328775422364 6.96133038565985 0.1371892769512045 0.05272608692202362 0.07160285409743812
# U2U3 -0.037541721612164784 8.32925896502173 -0.0366928870751293 0.6059682880974744 0.07266196667950561
# U3U3 1.0 0.0 1.0 0.0 0.0

# %%
import sys
sys.path.append('..\\..\\') # to pick up network_generator.py
sys.path.append('..\\..\\..\\') # to pick up network_generator.py
import plot_data as plot
filestem = "ExampleOne_Chain_U1XU2BU3Y_NetworkValues"
filename = filestem + ".csv"

plot.one_plot(filename, "Example1_3_node_chain_NetworkValues_plot_")
plot.all_against_all__superposed_scatter(filename, filestem + "_superposed_scatter_")
plot.all_against_all__individual_scatter(filename, filestem + "_individual_scatter_")
# Out:
# output file name stem:  ExampleOne_Chain_U1XU2BU3Y_NetworkValues_superposed_scatter_
# X X
# X B
# X Y
# X U1
# X U2
# X U3
# B X
# B B
# B Y
# B U1
# B U2
# B U3
# Y X
# Y B
# Y Y
# Y U1
# Y U2
# Y U3
# U1 X
# U1 B
# U1 Y
# U1 U1
# U1 U2
# U1 U3
# U2 X
# U2 B
# U2 Y
# U2 U1
# U2 U2
# U2 U3
# U3 X
# U3 B
# U3 Y
# U3 U1
# U3 U2
# U3 U3
# X X
# X B
# X Y
# X U1
# X U2
# X U3
# B X
# B B
# B Y
# B U1
# B U2
# B U3
# Y X
# Y B
# Y Y
# Y U1
# Y U2
# Y U3
# U1 X
# U1 B
# U1 Y
# U1 U1
# U1 U2
# U1 U3
# U2 X
# U2 B
# U2 Y
# U2 U1
# U2 U2
# U2 U3
# U3 X
# U3 B
# U3 Y
# U3 U1
# U3 U2
# U3 U3
