# %% [markdown]
# Scripts to analyse 1. Noise free data generated for X ->B -> Y 2.

# %%
from sys import *
sys.path.append('..\\..\\') 
sys.path.append('..\\..\\..\\') # to pick up network_generator.py
import calculate_write_pairwise_regression as pair_regress
filename = "ExampleOne_Chain_U1XU2BU3Y_NetworkValues.csv"

slope_dataframe, intercept_dataframe, correlation_dataframe, p_dataframe, std_err_dataframe = pair_regress.regress_from_csv(filename)
dictionary_dataframes = dict(zip(["slope", "intercept", "correlation", "p-value", "std_err"],
    [slope_dataframe, intercept_dataframe, correlation_dataframe, 
    p_dataframe, std_err_dataframe]))
for name in ["slope",  "intercept", "correlation"]:
    pair_regress.dataframe_to_html(dictionary_dataframes[name], name)
    pair_regress.dataframe_to_tex(dictionary_dataframes[name], name)
    pair_regress.dataframe_to_csv(dictionary_dataframes[name], name)
# Out:
# calculation_key, slope, intercept, r_value, p_value, std_err
# XX 1.0 0.0 1.0 0.0 0.0
# BX 0.6628519006358135 4.7485126768653405 0.5792915464039788 0.0 0.006595501260600156
# YX 0.36364357664598895 10.033817357633158 0.30384135931607925 0.0 0.008063103487808466
# U1X 0.992047913139646 8.10490427100098 0.7055852604787588 0.0 0.007045411393570968
# U2X 0.012344692976753509 15.934641846938211 0.008794264984465188 0.2136309114728574 0.009925917679276702
# U3X 0.0014553284690835234 16.021877237480936 0.0010386716415982365 0.8832257825544932 0.009908073836698058
# calculation_key, slope, intercept, r_value, p_value, std_err
# XB 0.506264967201909 8.90770064836819 0.5792915464039788 0.0 0.00503743177951971
# BB 1.0 0.0 1.0 0.0 0.0
# YB 0.543888334925055 8.051395139738503 0.5199960313126112 0.0 0.0063177156389902485
# U1B 0.5027109084654908 13.007159012907525 0.40912354730667455 0.0 0.007928543779459287
# U2B 1.0061723464883765 8.967320923469106 0.8201833455818692 0.0 0.004962958839638357
# U3B -0.004268455961056039 17.058989383264578 -0.0034858393600342907 0.6220529932891408 0.008658995521715038
# calculation_key, slope, intercept, r_value, p_value, std_err
# XY 0.25387378620169304 12.428314648935153 0.30384135931607925 0.0 0.00562916752130287
# BY 0.49715328536716147 8.034815031952613 0.5199960313126112 0.0 0.00577484914504058
# YY 1.0 0.0 1.0 0.0 0.0
# U1Y 0.25277198040081594 14.478608416839618 0.21516657823432447 3.7312939249023044e-208 0.008112738701120456
# U2Y 0.4980716590142361 12.510167443865145 0.4246587871923098 0.0 0.007508904936673297
# U3Y 0.9978657720194712 8.529494691632294 0.8523508640274174 0.0 0.004329497760857513
# calculation_key, slope, intercept, r_value, p_value, std_err
# XU1 0.5018412449750276 -0.05412160130710486 0.7055852604787588 0.0 0.0035640194170875675
# BU1 0.33295891165705016 2.323557824929887 0.40912354730667455 0.0 0.005251287098368699
# YU1 0.18315580831251912 4.97029894981341 0.21516657823432447 3.7312939249023044e-208 0.00587840160161667
# U1U1 1.0 0.0 1.0 0.0 0.0
# U2U1 0.006665356678293231 7.938772823916726 0.006676145555274536 0.3451180037010412 0.007059836398715515
# U3U1 0.0014067722965467172 7.980915024069474 0.0014116408079165458 0.8417748288137912 0.007047026229084286
# calculation_key, slope, intercept, r_value, p_value, std_err
# XU2 0.0062649672019084645 7.907700648368201 0.008794264984465188 0.2136309114728574 0.005037431779519711
# BU2 0.6685740496820929 -3.3742563384326623 0.8201833455818692 0.0 0.003297750630300083
# YU2 0.3620665466020604 2.0344864609219266 0.4246587871923098 0.0 0.005458498250161943
# U1U2 0.006686951895667348 7.954706877407043 0.006676145555274536 0.3451180037010412 0.0070827096985274325
# U2U2 1.0 0.0 1.0 0.0 0.0
# U3U2 -0.0049961201955977955 8.048050764524113 -0.005005308763240904 0.4790584454646518 0.007058351509609657
# calculation_key, slope, intercept, r_value, p_value, std_err
# XU3 0.0007413026007384861 7.974464324751059 0.0010386716415982365 0.8832257825544932 0.005046888767371242
# BU3 -0.0028467146328383414 8.03481503195261 -0.0034858393600342907 0.6220529932891408 0.005774849145040586
# YU3 0.7280558325374736 -4.025697569869269 0.8523508640274174 0.0 0.0031588578194951234
# U1U3 0.001416526168070656 7.975028910385854 0.0014116408079165458 0.8417748288137912 0.0070958868646207145
# U2U3 -0.005014514229952093 8.026506982130591 -0.005005308763240904 0.4790584454646518 0.00708433798612935
# U3U3 1.0 0.0 1.0 0.0 0.0

# %%
import sys
sys.path.append('..\\..\\') # to pick up network_generator.py
sys.path.append('..\\..\\..\\') # to pick up network_generator.py
import plot_data as plot
filestem = "ExampleOne_Chain_U1XU2BU3Y_NetworkValues"
filename = filestem + ".csv"

#one_plot("Example1_3_node_chain_NetworkValues.csv", "Example1_3_node_chain_NetworkValues_plot_")
plot.all_against_all__superposed_scatter(filename, filestem + "_superposed_scatter_")
plot.all_against_all__individual_scatter(filename, filestem + "_individual_scatter_")
# Out:
# output file name stem:  ExampleOne_Chain_U1XU2BU3Y_NetworkValues_superposed_scatter_
# X X
# X B
# X Y
# X U1
# X U2
# X U3
# B X
# B B
# B Y
# B U1
# B U2
# B U3
# Y X
# Y B
# Y Y
# Y U1
# Y U2
# Y U3
# U1 X
# U1 B
# U1 Y
# U1 U1
# U1 U2
# U1 U3
# U2 X
# U2 B
# U2 Y
# U2 U1
# U2 U2
# U2 U3
# U3 X
# U3 B
# U3 Y
# U3 U1
# U3 U2
# U3 U3
# X X
# X B
# X Y
# X U1
# X U2
# X U3
# B X
# B B
# B Y
# B U1
# B U2
# B U3
# Y X
# Y B
# Y Y
# Y U1
# Y U2
# Y U3
# U1 X
# U1 B
# U1 Y
# U1 U1
# U1 U2
# U1 U3
# U2 X
# U2 B
# U2 Y
# U2 U1
# U2 U2
# U2 U3
# U3 X
# U3 B
# U3 Y
# U3 U1
# U3 U2
# U3 U3
