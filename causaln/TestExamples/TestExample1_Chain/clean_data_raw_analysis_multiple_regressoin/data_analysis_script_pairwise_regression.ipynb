# %% [markdown]
# Scripts to analyse 1. Noise free data generated for X ->B -> Y 2.

# %%
from sys import *
sys.path.append('..\\..\\') # to pick up network_generator.py
sys.path.append('..\\..\\..\\') # to pick up network_generator.py
from network_generator import *
from calculate_write_regression import *

slope_dataframe, intercept_dataframe, correlation_dataframe, p_dataframe, std_err_dataframe = regress_from_csv("Example1_3_node_chain_NetworkValues.csv")
dictionary_dataframes = dict(zip(["slope", "intercept", "correlation", "p-value", "std_err"],
    [slope_dataframe, intercept_dataframe, correlation_dataframe, 
    p_dataframe, std_err_dataframe]))
for name in ["slope",  "intercept", "correlation"]:
    dataframe_to_html(dictionary_dataframes[name], name)
    dataframe_to_tex(dictionary_dataframes[name], name)
    dataframe_to_csv(dictionary_dataframes[name], name)
# Out:
# calculation_key, slope, intercept, r_value, p_value, std_err
# XX 1.0 0.0 1.0 1.9648061969921602e-129 0.0
# BX 2.0 -2.0 1.0 1.9648061969921602e-129 0.0
# YX 4.0 -2.0 1.0 1.9648061969921602e-129 0.0
# calculation_key, slope, intercept, r_value, p_value, std_err
# XB 0.5 1.0 1.0 1.9648061969921602e-129 0.0
# BB 1.0 0.0 1.0 1.9648061969921602e-129 0.0
# YB 2.0 0.0 1.0 1.9648061969921602e-129 0.0
# calculation_key, slope, intercept, r_value, p_value, std_err
# XY 0.25 0.5 1.0 1.9648061969921602e-129 0.0
# BY 0.5 0.0 1.0 1.9648061969921602e-129 0.0
# YY 1.0 0.0 1.0 1.9648061969921602e-129 0.0

# %%
import sys
sys.path.append('..\\..\\') # to pick up network_generator.py
sys.path.append('..\\..\\..\\') # to pick up network_generator.py
from plot_data import *

#one_plot("Example1_3_node_chain_NetworkValues.csv", "Example1_3_node_chain_NetworkValues_plot_")
all_against_all__superposed_scatter("Example1_3_node_chain_NetworkValues.csv", "Example1_3_node_chain_NetworkValues_superposed_scatter_")
all_against_all__individual_scatter("Example1_3_node_chain_NetworkValues.csv", "Example1_3_node_chain_NetworkValues_individual_scatter_")
# Out:
# output file name stem:  Example1_3_node_chain_NetworkValues_superposed_scatter_
# X X
# X B
# X Y
# B X
# B B
# B Y
# Y X
# Y B
# Y Y
# X X
# X B
# X Y
# B X
# B B
# B Y
# Y X
# Y B
# Y Y
