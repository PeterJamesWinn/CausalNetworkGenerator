# %%
import sys
import numpy as np
sys.path.append('..\\..\\..\\') # to pick up network_generator.py
import multiple_regression_random_initialisation as mregress
# Jupyter Notebook will carry over previous variable values, so reset for this next run
if "all_regression_out_parameters" in locals():
     del all_regression_out_parameters 
if "regression_parameters" in locals():
    del regression_parameters

# not a random initialisation
input_csv = "Example1_3_node_chain_NetworkValues.csv"
counter = 0 
while counter < 1:
    regression_parameters = mregress.multi_regress_from_csv_2(input_csv, \
        threshold=0.0001, random = 0, max_iter = 1000000, learning_rate = 0.0005)

    if "all_regression_out_parameters" in locals():
        all_regression_out_parameters = np.append(all_regression_out_parameters, regression_parameters, axis=0)
    else:
        all_regression_out_parameters = regression_parameters
    #print("regression_parameters: \n", regression_parameters)
    #print("all_regression_parameters: \n", all_regression_out_parameters)
    counter += 1
print("all_regression_parameters: \n", all_regression_out_parameters)
# Out:
# Calling Regression with threshold = 0.0001, random =             0, max_iter = 1000000
# random,  0
# setting initial parameters using gradient estimates.
# Calling Regression with threshold = 0.0001, random =             0, max_iter = 1000000
# random,  0
# setting initial parameters using gradient estimates.
# Calling Regression with threshold = 0.0001, random =             0, max_iter = 1000000
# random,  0
# setting initial parameters using gradient estimates.
# all_regression_parameters:
#  [['  ' '  ']
#  ['dependent' 'X']
#  ['intercept' '-1.9747887068147099']
#  ['B' '1.5680151395797113']
#  ['Y' '0.855436141218427']
#  ['r_squared ' array([0.99999464])]
#  ['  ' '  ']
#  ['dependent' 'B']
#  ['intercept' '0.649437840631145']
#  ['X' '0.33728890493698477']
#  ['Y' '0.6590411465498182']
#  ['r_squared ' array([0.99997857])]
#  ['  ' '  ']
#  ['dependent' 'Y']
#  ['intercept' '0.019601158928897317']
#  ['X' '0.022382889768460052']
#  ['B' '0.4593640323845578']
#  ['r_squared ' array([0.9999143])]]

# %% [markdown]
# # three random initialisations - small max_iter - may not converge will then repeat with higher iteration number to see how much further it optimises.

# %%
import sys
import numpy as np
sys.path.append('..\\..\\..\\') # to pick up network_generator.py
import multiple_regression_random_initialisation as mregress
# Jupyter Notebook will carry over previous variable values, so reset for this next run
if "all_regression_out_parameters" in locals():
     del all_regression_out_parameters 
if "regression_parameters" in locals():
    del regression_parameters

# three random initialisations - small max_iter - may not converge
input_csv = "Example1_3_node_chain_NetworkValues.csv"
counter = 0 
while counter < 3:
    regression_parameters = mregress.multi_regress_from_csv_2(input_csv, \
        threshold=0.0001, random = 1, max_iter = 100000, learning_rate = 0.0005)

    if "all_regression_out_parameters" in locals():
        all_regression_out_parameters = np.append(all_regression_out_parameters, regression_parameters, axis=0)
    else:
        all_regression_out_parameters = regression_parameters
    #print("regression_parameters: \n", regression_parameters)
    #print("all_regression_parameters: \n", all_regression_out_parameters)
    counter += 1
print("all_regression_parameters: \n", all_regression_out_parameters)
# Out:
# Calling Regression with threshold = 0.0001, random =             1, max_iter = 100000
# random,  1
# using pseudo random initial parameter values.
# Calling Regression with threshold = 0.0001, random =             1, max_iter = 100000
# random,  1
# using pseudo random initial parameter values.
# Calling Regression with threshold = 0.0001, random =             1, max_iter = 100000
# random,  1
# using pseudo random initial parameter values.
# Calling Regression with threshold = 0.0001, random =             1, max_iter = 100000
# random,  1
# using pseudo random initial parameter values.
# Calling Regression with threshold = 0.0001, random =             1, max_iter = 100000
# random,  1
# using pseudo random initial parameter values.
# Calling Regression with threshold = 0.0001, random =             1, max_iter = 100000
# random,  1
# using pseudo random initial parameter values.
# Calling Regression with threshold = 0.0001, random =             1, max_iter = 100000
# random,  1
# using pseudo random initial parameter values.
# Calling Regression with threshold = 0.0001, random =             1, max_iter = 100000
# random,  1
# using pseudo random initial parameter values.
# Calling Regression with threshold = 0.0001, random =             1, max_iter = 100000
# random,  1
# using pseudo random initial parameter values.
# all_regression_parameters:
#  [['  ' '  ']
#  ['dependent' 'X']
#  ['intercept' '-1.9447882027331442']
#  ['B' '1.4665943345798615']
#  ['Y' '1.0481231078841584']
#  ['r_squared ' array([0.99997431])]
#  ['  ' '  ']
#  ['dependent' 'B']
#  ['intercept' '0.729851532870409']
#  ['X' '0.37749594908091716']
#  ['Y' '0.4982130991038342']
#  ['r_squared ' array([0.99997857])]
#  ['  ' '  ']
#  ['dependent' 'Y']
#  ['intercept' '0.1052197814025633']
#  ['X' '0.053890988310051534']
#  ['B' '0.39443123512140393']
#  ['r_squared ' array([0.99991842])]
#  ['  ' '  ']
#  ['dependent' 'X']
#  ['intercept' '-1.9458023764355474']
#  ['B' '1.6211034662641988']
#  ['Y' '0.739448124488333']
#  ['r_squared ' array([0.99997524])]
#  ['  ' '  ']
#  ['dependent' 'B']
#  ['intercept' '0.6591372773794463']
#  ['X' '0.34213887269981746']
#  ['Y' '0.6396414381224536']
#  ['r_squared ' array([0.99997857])]
#  ['  ' '  ']
#  ['dependent' 'Y']
#  ['intercept' '0.0006231160998447996']
#  ['X' '-0.012271606508668428']
#  ['B' '0.5204131207092958']
#  ['r_squared ' array([0.99991429])]
#  ['  ' '  ']
#  ['dependent' 'X']
#  ['intercept' '-1.9542170481031107']
#  ['B' '1.409388584729102']
#  ['Y' '1.1657261060192659']
#  ['r_squared ' array([0.99998233])]
#  ['  ' '  ']
#  ['dependent' 'B']
#  ['intercept' '0.8265811404267853']
#  ['X' '0.40072063669185215']
#  ['Y' '0.38892072025656943']
#  ['r_squared ' array([0.99997857])]
#  ['  ' '  ']
#  ['dependent' 'Y']
#  ['intercept' '0.34392830448835476']
#  ['X' '0.18454658546892203']
#  ['B' '0.13503668132912647']
#  ['r_squared ' array([0.9999143])]]

# %% [markdown]
# tenfold more iterations than the previous optimisations.

# %%
import sys
import numpy as np
sys.path.append('..\\..\\..\\') # to pick up network_generator.py
import multiple_regression_random_initialisation as mregress
# Jupyter Notebook will carry over previous variable values, so reset for this next run
if "all_regression_out_parameters" in locals():
     del all_regression_out_parameters 
if "regression_parameters" in locals():
    del regression_parameters

input_csv = "Example1_3_node_chain_NetworkValues.csv"
counter = 0 
while counter < 2:
    regression_parameters = mregress.multi_regress_from_csv_2(input_csv, \
        threshold=0.0001, random = 1, max_iter = 1000000, learning_rate = 0.0005)

    if "all_regression_out_parameters" in locals():
        all_regression_out_parameters = np.append(all_regression_out_parameters, regression_parameters, axis=0)
    else:
        all_regression_out_parameters = regression_parameters
    #print("regression_parameters: \n", regression_parameters)
    #print("all_regression_parameters: \n", all_regression_out_parameters)
    counter += 1
print("all_regression_parameters: \n", all_regression_out_parameters)
# Out:
# Calling Regression with threshold = 0.0001, random =             1, max_iter = 1000000
# random,  1
# using pseudo random initial parameter values.
# Calling Regression with threshold = 0.0001, random =             1, max_iter = 1000000
# random,  1
# using pseudo random initial parameter values.
# Calling Regression with threshold = 0.0001, random =             1, max_iter = 1000000
# random,  1
# using pseudo random initial parameter values.
# Calling Regression with threshold = 0.0001, random =             1, max_iter = 1000000
# random,  1
# using pseudo random initial parameter values.
# Calling Regression with threshold = 0.0001, random =             1, max_iter = 1000000
# random,  1
# using pseudo random initial parameter values.
# Calling Regression with threshold = 0.0001, random =             1, max_iter = 1000000
# random,  1
# using pseudo random initial parameter values.
# all_regression_parameters:
#  [['  ' '  ']
#  ['dependent' 'X']
#  ['intercept' '-1.974788121525767']
#  ['B' '1.4800178218164641']
#  ['Y' '1.0314305786348996']
#  ['r_squared ' array([0.99999464])]
#  ['  ' '  ']
#  ['dependent' 'B']
#  ['intercept' '0.917727822175898']
#  ['X' '0.4462934630817479']
#  ['Y' '0.20662907920647905']
#  ['r_squared ' array([0.99997857])]
#  ['  ' '  ']
#  ['dependent' 'Y']
#  ['intercept' '0.22063067092824312']
#  ['X' '0.12289858685610015']
#  ['B' '0.25833294709661325']
#  ['r_squared ' array([0.99991429])]
#  ['  ' '  ']
#  ['dependent' 'X']
#  ['intercept' '-1.974788243129604']
#  ['B' '1.5054853816131122']
#  ['Y' '0.9804955002023669']
#  ['r_squared ' array([0.99999464])]
#  ['  ' '  ']
#  ['dependent' 'B']
#  ['intercept' '0.6466128726222712']
#  ['X' '0.3107359220322615']
#  ['Y' '0.7488592001886505']
#  ['r_squared ' array([0.99997857])]
#  ['  ' '  ']
#  ['dependent' 'Y']
#  ['intercept' '-0.08411309491061228']
#  ['X' '-0.05463928538470139']
#  ['B' '0.605148618491157']
#  ['r_squared ' array([0.9999143])]]
