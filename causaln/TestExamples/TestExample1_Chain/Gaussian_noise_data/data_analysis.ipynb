# %% [markdown]
# Scripts to analyse 1. Noise free data generated for X ->B -> Y 2. the data from 1. with Gaussian noise added.

# %%
from sys import *
sys.path.append('..\\..\\') # to pick regression coed
sys.path.append('..\\..\\..\\')
import calculate_write_regression as regression

slope_dataframe, intercept_dataframe, correlation_dataframe, p_dataframe, std_err_dataframe = regression.regress_from_csv("Example1_3_node_chain_NetworkValues_noisy.csv")
dictionary_dataframes = dict(zip(["slope", "intercept", "correlation", "p-value", "std_err"],
    [slope_dataframe, intercept_dataframe, correlation_dataframe, 
    p_dataframe, std_err_dataframe]))
for name in ["slope",  "intercept", "correlation"]:
    regression.dataframe_to_html(dictionary_dataframes[name], name)
    regression.dataframe_to_tex(dictionary_dataframes[name], name)
    regression.dataframe_to_csv(dictionary_dataframes[name], name)
# Out:
# calculation_key, slope, intercept, r_value, p_value, std_err
# XX 1.0 0.0 1.0 0.0 0.0
# BX 1.8749793593260862 -1.2460452409199316 0.9530050570322387 6.336323967864159e-24 0.09089590238803776
# YX 3.7821840204137054 -1.5646842085856445 0.9538262598062499 4.3732188237370985e-24 0.18162668292741993
# calculation_key, slope, intercept, r_value, p_value, std_err
# XB 0.4843886063126885 1.0650090983228422 0.9530050570322387 6.336323967864159e-24 0.023482359556801134
# BB 1.0 0.0 1.0 0.0 0.0
# YB 1.917747909439187 0.08627450614759091 0.9515232913123505 1.2169040718933929e-23 0.0945347106396291
# calculation_key, slope, intercept, r_value, p_value, std_err
# XY 0.2405447564120545 0.6088278889260275 0.9538262598062499 4.3732188237370985e-24 0.011551353917974311
# BY 0.4721144887988204 0.2030259843918789 0.9515232913123505 1.2169040718933929e-23 0.02327271815429826
# YY 1.0 0.0 1.0 0.0 0.0

# %%
import sys
sys.path.append('..\\..\\') # to pick up network_generator.py
import plot_data as plot

#plot.one_plot("Example1_3_node_chain_NetworkValues.csv", "Example1_3_node_chain_NetworkValues_plot_")
plot.all_against_all__superposed_scatter("Example1_3_node_chain_NetworkValues_noisy.csv", "Example1_3_node_chain_NetworkValues_superposed_scatter_")
#plot.all_against_all__individual_scatter("Example1_3_node_chain_NetworkValues.csv", "Example1_3_node_chain_NetworkValues_individual_scatter_")
# Out:
# output file name stem:  Example1_3_node_chain_NetworkValues_superposed_scatter_
# X X
# X B
# X Y
# B X
# B B
# B Y
# Y X
# Y B
# Y Y
