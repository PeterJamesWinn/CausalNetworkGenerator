# %%
import pandas as pd
import numpy as np
import sys as sys
sys.path.append("..\\..\..\\")
import multiple_regression_random_initialisation as mregress

input_csv = "ExampleThree_Collider_NetworkValues.csv"
counter = 0 
while counter < 1:
    regression_parameters = mregress.multi_regress_from_csv_2(input_csv, \
        threshold=0.00001, random = 0, max_iter = 1, learning_rate = 0.01)

    if "all_regression_out_parameters" in locals():
        all_regression_out_parameters = np.append(all_regression_out_parameters,\
                                             regression_parameters, axis=0)
    else:
        all_regression_out_parameters = regression_parameters
    counter += 1
print("all_regression_parameters: \n", all_regression_out_parameters)
# Out:
# Calling Regression with threshold = 1e-05, random =             0, max_iter = 1
# random,  0
# setting initial parameters using gradient estimates.
# Calling Regression with threshold = 1e-05, random =             0, max_iter = 1
# random,  0
# setting initial parameters using gradient estimates.
# Calling Regression with threshold = 1e-05, random =             0, max_iter = 1
# random,  0
# setting initial parameters using gradient estimates.
# all_regression_parameters:
#  [['  ' '  ']
#  ['dependent' 'X']
#  ['intercept' '-0.02190283435697115']
#  ['Y' '0.2918057920582932']
#  ['B' '0.47448108338822115']
#  ['r_squared ' array([0.09706031])]
#  ['  ' '  ']
#  ['dependent' 'Y']
#  ['intercept' '-0.018868880354352677']
#  ['X' '0.2903213555664062']
#  ['B' '0.43988599494866076']
#  ['r_squared ' array([-0.00371299])]
#  ['  ' '  ']
#  ['dependent' 'B']
#  ['intercept' '0.0033966981214887527']
#  ['X' '0.5853178240212429']
#  ['Y' '0.8125908471954003']
#  ['r_squared ' array([-0.1173564])]]
# <__array_function__ internals>:5: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.

# %%
import pandas as pd
import numpy as np
import sys as sys
sys.path.append("..\\..\..\\")
import multiple_regression_random_initialisation as mregress
# Jupyter Notebook will carry over previous variable values, so reset for this next run
del all_regression_out_parameters, regression_parameters

input_csv = "ExampleThree_Collider_NetworkValues.csv"
counter = 0 
while counter < 1:
    regression_parameters = mregress.multi_regress_from_csv_2(input_csv, \
        threshold=0.00001, random = 0, max_iter = 10000, learning_rate = 0.01)

    if "all_regression_out_parameters" in locals():
        all_regression_out_parameters = np.append(all_regression_out_parameters,\
                                             regression_parameters, axis=0)
    else:
        all_regression_out_parameters = regression_parameters
    counter += 1
print("all_regression_parameters: \n", all_regression_out_parameters)
# Out:
# Calling Regression with threshold = 1e-05, random =             0, max_iter = 10000
# random,  0
# setting initial parameters using gradient estimates.
# Calling Regression with threshold = 1e-05, random =             0, max_iter = 10000
# random,  0
# setting initial parameters using gradient estimates.
# Calling Regression with threshold = 1e-05, random =             0, max_iter = 10000
# random,  0
# setting initial parameters using gradient estimates.
# all_regression_parameters:
#  [['  ' '  ']
#  ['dependent' 'X']
#  ['intercept' '-8.432784068167443']
#  ['Y' '-0.5814217544490448']
#  ['B' '1.8498384083958508']
#  ['r_squared ' array([0.99350843])]
#  ['  ' '  ']
#  ['dependent' 'Y']
#  ['intercept' '-12.353501070397042']
#  ['X' '-1.489320065533542']
#  ['B' '2.8281763756052802']
#  ['r_squared ' array([0.97366603])]
#  ['  ' '  ']
#  ['dependent' 'B']
#  ['intercept' '4.987872559263259']
#  ['X' '0.5008348123184626']
#  ['Y' '0.3006015975780988']
#  ['r_squared ' array([0.99999638])]]

# %%
import pandas as pd
import numpy as np
import sys as sys
sys.path.append("..\\..\..\\")
import multiple_regression_random_initialisation as mregress
# delete previously define variables - Jupyter notebook 
# (at least the version on vsstudio keeps them between code instances - that's the point!)
del all_regression_out_parameters, regression_parameters

input_csv = "ExampleThree_Collider_NetworkValues.csv"
counter = 0 
while counter < 1:
    regression_parameters = mregress.multi_regress_from_csv_2(input_csv, \
        threshold=0.00001, random = 0, max_iter = 100000, learning_rate = 0.01)

    if "all_regression_out_parameters" in locals():
        all_regression_out_parameters = np.append(all_regression_out_parameters,\
                                             regression_parameters, axis=0)
    else:
        all_regression_out_parameters = regression_parameters
    counter += 1
print("all_regression_parameters: \n", all_regression_out_parameters)
# Out:
# Calling Regression with threshold = 1e-05, random =             0, max_iter = 100000
# random,  0
# setting initial parameters using gradient estimates.
# Calling Regression with threshold = 1e-05, random =             0, max_iter = 100000
# random,  0
# setting initial parameters using gradient estimates.
# Calling Regression with threshold = 1e-05, random =             0, max_iter = 100000
# random,  0
# setting initial parameters using gradient estimates.
# all_regression_parameters:
#  [['  ' '  ']
#  ['dependent' 'X']
#  ['intercept' '-9.983670591552489']
#  ['Y' '-0.5998064263170901']
#  ['B' '1.998435410263112']
#  ['r_squared ' array([0.9999993])]
#  ['  ' '  ']
#  ['dependent' 'Y']
#  ['intercept' '-16.64764086788253']
#  ['X' '-1.6658843733201916']
#  ['B' '3.3311050361771906']
#  ['r_squared ' array([0.99999949])]
#  ['  ' '  ']
#  ['dependent' 'B']
#  ['intercept' '4.9909218152300445']
#  ['X' '0.5006249117715561']
#  ['Y' '0.3004503352429992']
#  ['r_squared ' array([0.99999797])]]

# %%
import pandas as pd
import numpy as np
import sys as sys
sys.path.append("..\\..\..\\")
import multiple_regression_random_initialisation as mregress
# delete previously define variables - Jupyter notebook 
# (at least the version on vsstudio keeps them between code instances - that's the point!)
del all_regression_out_parameters, regression_parameters

input_csv = "ExampleThree_Collider_NetworkValues.csv"
counter = 0 
while counter < 2:
    regression_parameters = mregress.multi_regress_from_csv_2(input_csv, \
        threshold=0.00001, random = 1, max_iter = 1000, learning_rate = 0.01)

    if "all_regression_out_parameters" in locals():
        all_regression_out_parameters = np.append(all_regression_out_parameters,\
                                             regression_parameters, axis=0)
    else:
        all_regression_out_parameters = regression_parameters
    counter += 1
print("all_regression_parameters: \n", all_regression_out_parameters)
# Out:
# Calling Regression with threshold = 1e-05, random =             1, max_iter = 1000
# random,  1
# using pseudo random initial parameter values.
# Calling Regression with threshold = 1e-05, random =             1, max_iter = 1000
# random,  1
# using pseudo random initial parameter values.
# Calling Regression with threshold = 1e-05, random =             1, max_iter = 1000
# random,  1
# using pseudo random initial parameter values.
# Calling Regression with threshold = 1e-05, random =             1, max_iter = 1000
# random,  1
# using pseudo random initial parameter values.
# Calling Regression with threshold = 1e-05, random =             1, max_iter = 1000
# random,  1
# using pseudo random initial parameter values.
# Calling Regression with threshold = 1e-05, random =             1, max_iter = 1000
# random,  1
# using pseudo random initial parameter values.
# all_regression_parameters:
#  [['  ' '  ']
#  ['dependent' 'X']
#  ['intercept' '-0.9073587973700108']
#  ['Y' '-0.492213116560354']
#  ['B' '1.128795562155974']
#  ['r_squared ' array([0.78148969])]
#  ['  ' '  ']
#  ['dependent' 'Y']
#  ['intercept' '-1.5587265053022537']
#  ['X' '-1.0454658854303294']
#  ['B' '1.5638948735049567']
#  ['r_squared ' array([0.67690174])]
#  ['  ' '  ']
#  ['dependent' 'B']
#  ['intercept' '2.698371593738555']
#  ['X' '0.658436374811498']
#  ['Y' '0.4141752909742383']
#  ['r_squared ' array([0.86971743])]
#  ['  ' '  ']
#  ['dependent' 'X']
#  ['intercept' '-0.8291283579346435']
#  ['Y' '-0.4912857495754549']
#  ['B' '1.121299972646639']
#  ['r_squared ' array([0.77771352])]
#  ['  ' '  ']
#  ['dependent' 'Y']
#  ['intercept' '-1.746090947714455']
#  ['X' '-1.0531698435516934']
#  ['B' '1.58583895370985']
#  ['r_squared ' array([0.68486599])]
#  ['  ' '  ']
#  ['dependent' 'B']
#  ['intercept' '2.381432854446539']
#  ['X' '0.6802533739214097']
#  ['Y' '0.4298974521542231']
#  ['r_squared ' array([0.8313667])]]

# %%
import pandas as pd
import numpy as np
import sys as sys
sys.path.append("..\\..\..\\")
import multiple_regression_random_initialisation as mregress
# delete previously define variables - Jupyter notebook 
# (at least the version on vsstudio keeps them between code instances - that's the point!)
del all_regression_out_parameters, regression_parameters

input_csv = "ExampleThree_Collider_NetworkValues.csv"
counter = 0 
while counter < 2:
    regression_parameters = mregress.multi_regress_from_csv_2(input_csv, \
        threshold=0.00001, random = 1, max_iter = 100000, learning_rate = 0.01)

    if "all_regression_out_parameters" in locals():
        all_regression_out_parameters = np.append(all_regression_out_parameters,\
                                             regression_parameters, axis=0)
    else:
        all_regression_out_parameters = regression_parameters
    counter += 1
print("all_regression_parameters: \n", all_regression_out_parameters)
# Out:
# Calling Regression with threshold = 1e-05, random =             1, max_iter = 100000
# random,  1
# using pseudo random initial parameter values.
# Calling Regression with threshold = 1e-05, random =             1, max_iter = 100000
# random,  1
# using pseudo random initial parameter values.
# Calling Regression with threshold = 1e-05, random =             1, max_iter = 100000
# random,  1
# using pseudo random initial parameter values.
# Calling Regression with threshold = 1e-05, random =             1, max_iter = 100000
# random,  1
# using pseudo random initial parameter values.
# Calling Regression with threshold = 1e-05, random =             1, max_iter = 100000
# random,  1
# using pseudo random initial parameter values.
# Calling Regression with threshold = 1e-05, random =             1, max_iter = 100000
# random,  1
# using pseudo random initial parameter values.
# all_regression_parameters:
#  [['  ' '  ']
#  ['dependent' 'X']
#  ['intercept' '-9.983668933880114']
#  ['Y' '-0.5998064066665469']
#  ['B' '1.9984352514345058']
#  ['r_squared ' array([0.9999993])]
#  ['  ' '  ']
#  ['dependent' 'Y']
#  ['intercept' '-16.647640486497792']
#  ['X' '-1.6658843576386027']
#  ['B' '3.331104991509498']
#  ['r_squared ' array([0.99999949])]
#  ['  ' '  ']
#  ['dependent' 'B']
#  ['intercept' '4.990923334482953']
#  ['X' '0.5006248071912848']
#  ['Y' '0.30045025987846924']
#  ['r_squared ' array([0.99999797])]
#  ['  ' '  ']
#  ['dependent' 'X']
#  ['intercept' '-9.983670820101299']
#  ['Y' '-0.5998064290263762']
#  ['B' '1.9984354321613411']
#  ['r_squared ' array([0.9999993])]
#  ['  ' '  ']
#  ['dependent' 'Y']
#  ['intercept' '-16.647642405380786']
#  ['X' '-1.6658844365382806']
#  ['B' '3.3311052162486305']
#  ['r_squared ' array([0.99999949])]
#  ['  ' '  ']
#  ['dependent' 'B']
#  ['intercept' '4.990920113706916']
#  ['X' '0.5006250288986976']
#  ['Y' '0.30045041964928204']
#  ['r_squared ' array([0.99999797])]]
