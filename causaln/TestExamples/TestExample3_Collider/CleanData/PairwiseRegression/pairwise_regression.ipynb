# %% [markdown]
# Contains: Pairwise comparisons; pairwise plots; multiple linear regression (random initialisations)

# %% [markdown]
# Pairwise comparisons

# %%
import sys as sys
sys.path.append('..\\..\\..\\..\\') 
sys.path.append('..\\..\\..\\') #to pick up calculate_write_pairwise_regression 
import calculate_write_pairwise_regression as pair_regress

csv_file = "..\\ExampleThree_Collider_NetworkValues.csv"
slope_dataframe, intercept_dataframe, correlation_dataframe, p_dataframe, \
    std_err_dataframe = pair_regress.regress_from_csv(csv_file)
dictionary_dataframes = dict(zip(["slope", "intercept", "correlation", \
    "p-value", "std_err"],
    [slope_dataframe, intercept_dataframe, correlation_dataframe, 
    p_dataframe, std_err_dataframe]))
for name in ["slope",  "intercept", "correlation"]:
    pair_regress.dataframe_to_html(dictionary_dataframes[name], name)
    pair_regress.dataframe_to_tex(dictionary_dataframes[name], name)
    pair_regress.dataframe_to_csv(dictionary_dataframes[name], name)
# Out:
# calculation_key, slope, intercept, r_value, p_value, std_err
# XX 1.0 0.0 1.0 4.7338110351560214e-297 0.0
# YX -0.06370414852624731 7.995095831456738 -0.07471539403816892 0.6844433584819027 0.15523205255303751
# BX 1.3631465517241383 -7.395204741379313 0.8035779642299263 3.072138677697712e-08 0.18433867739172738
# calculation_key, slope, intercept, r_value, p_value, std_err
# XY -0.08762993047428926 7.941212913884491 -0.07471539403816892 0.6844433584819027 0.21353356551024635
# YY 1.0 0.0 1.0 4.7338110351560214e-297 0.0
# BY 1.061422413793104 -4.341325431034489 0.5334962217197505 0.0016647032950828891 0.3072311289862122
# calculation_key, slope, intercept, r_value, p_value, std_err
# XB 0.47371102085771305 7.382363874165348 0.8035779642299263 3.072138677697712e-08 0.0640600696530739
# YB 0.26814792573687635 8.997547915728369 0.5334962217197505 0.0016647032950828891 0.07761602627651873
# BB 1.0 0.0 1.0 4.7338110351560214e-297 0.0

# %% [markdown]
# Pairwise plots

# %%
import sys
sys.path.append('..\\..\\') # to pick up network_generator.py
sys.path.append('..\\..\\..\\') # to pick up network_generator.py
import plot_data as plot

#one_plot
plot.all_against_all__superposed_scatter(csv_file, "ExampleThree_Collider_NetworkValues_superposed_scatter_")
plot.all_against_all__individual_scatter(csv_file, "ExampleThree_Collider_NetworkValues_individual_scatter_")
# Out:
# output file name stem:  ExampleThree_Collider_NetworkValues_superposed_scatter_
# X X
# X Y
# X B
# Y X
# Y Y
# Y B
# B X
# B Y
# B B
# X X
# X Y
# X B
# Y X
# Y Y
# Y B
# B X
# B Y
# B B
