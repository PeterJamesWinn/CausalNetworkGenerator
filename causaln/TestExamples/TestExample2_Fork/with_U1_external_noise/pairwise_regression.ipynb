# %% [markdown]
# Contains: Pairwise comparisons; pairwise plots; multiple linear regression (random initialisations)

# %% [markdown]
# Pairwise comparisons

# %%
import sys as sys
sys.path.append('..\\..\\') 
sys.path.append('..\\..\\..\\') #to pick up calculate_write_pairwise_regression 
import calculate_write_pairwise_regression as pair_regress

csv_file = "ExampleTwo_SimpleFork_U1_Noise_NetworkValues_butU1deleted.csv"
slope_dataframe, intercept_dataframe, correlation_dataframe, p_dataframe, \
    std_err_dataframe = pair_regress.regress_from_csv(csv_file)
dictionary_dataframes = dict(zip(["slope", "intercept", "correlation", \
    "p-value", "std_err"],
    [slope_dataframe, intercept_dataframe, correlation_dataframe, 
    p_dataframe, std_err_dataframe]))
for name in ["slope",  "intercept", "correlation"]:
    pair_regress.dataframe_to_html(dictionary_dataframes[name], name)
    pair_regress.dataframe_to_tex(dictionary_dataframes[name], name)
    pair_regress.dataframe_to_csv(dictionary_dataframes[name], name)
# Out:
# calculation_key, slope, intercept, r_value, p_value, std_err
# XX 1.0 0.0 1.0 0.0 0.0
# BX 0.5662351376720901 8.010716520650814 0.5452705527748276 4.466843172557554e-09 0.08793272613903991
# YX 1.887450458906969 8.010716520650808 0.5452705527748279 4.466843172557423e-09 0.293109087130133
# calculation_key, slope, intercept, r_value, p_value, std_err
# XB 0.5250821715969624 1.3027269636178191 0.5452705527748276 4.466843172557554e-09 0.08154193147629502
# BB 1.0 0.0 1.0 0.0 0.0
# YB 3.3333333333333357 -5.329070518200751e-15 1.0 0.0 0.0
# calculation_key, slope, intercept, r_value, p_value, std_err
# XY 0.15752465147908876 0.390818089085345 0.5452705527748279 4.466843172557423e-09 0.02446257944288849
# BY 0.30000000000000004 -4.440892098500626e-16 1.0 0.0 0.0
# YY 1.0 0.0 1.0 0.0 0.0

# %% [markdown]
# Pairwise plots

# %%
import sys
sys.path.append('..\\..\\') # to pick up network_generator.py
sys.path.append('..\\..\\..\\') # to pick up network_generator.py
import plot_data as plot

#one_plot
plot.all_against_all__superposed_scatter(csv_file, "ExampleTwo_SimpleFork_U1_Noise_NetworkValues_butU1deleted_superposed_scatter_")
plot.all_against_all__individual_scatter(csv_file, "ExampleTwo_SimpleFork_U1_Noise_NetworkValues_butU1deleted_individual_scatter_")
# Out:
# output file name stem:  ExampleTwo_SimpleFork_U1_Noise_NetworkValues_butU1deleted_superposed_scatter_
# X X
# X B
# X Y
# B X
# B B
# B Y
# Y X
# Y B
# Y Y
# X X
# X B
# X Y
# B X
# B B
# B Y
# Y X
# Y B
# Y Y
