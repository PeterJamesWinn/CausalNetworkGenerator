# %%
import numpy as np
import sys as sys
sys.path.append("..\\..\..\\")
import multiple_regression_random_initialisation as mregress

input_csv = "ExampleTwo_SimpleFork_U1_Noise_NetworkValues_butU1deleted.csv"
counter = 0 
while counter < 1:
    regression_parameters = mregress.multi_regress_from_csv_2(input_csv, \
        threshold=0.00001, random = 0, max_iter = 1, learning_rate = 0.01)

    if "all_regression_out_parameters" in locals():
        all_regression_out_parameters = np.append(all_regression_out_parameters,\
                                             regression_parameters, axis=0)
    else:
        all_regression_out_parameters = regression_parameters
    counter += 1
print("all_regression_parameters: \n", all_regression_out_parameters)
# Out:
# Calling Regression with threshold = 1e-05, random =             0, max_iter = 1
# random,  0
# setting initial parameters using gradient estimates.
# Calling Regression with threshold = 1e-05, random =             0, max_iter = 1
# random,  0
# setting initial parameters using gradient estimates.
# Calling Regression with threshold = 1e-05, random =             0, max_iter = 1
# random,  0
# setting initial parameters using gradient estimates.
# all_regression_parameters:
#  [['  ' '  ']
#  ['dependent' 'X']
#  ['intercept' '0.07004314963692307']
#  ['B' '0.8311262209723077']
#  ['Y' '0.8236968406506666']
#  ['r_squared ' array([-0.64476903])]
#  ['  ' '  ']
#  ['dependent' 'B']
#  ['intercept' '-0.01745958394714286']
#  ['X' '0.41484847132339286']
#  ['Y' '1.123022454299']
#  ['r_squared ' array([0.68611509])]
#  ['  ' '  ']
#  ['dependent' 'Y']
#  ['intercept' '-0.20667839260714277']
#  ['X' '-0.6297156011428569']
#  ['B' '1.7095695017500003']
#  ['r_squared ' array([-19.56206006])]]

# %%
import pandas as pd
import numpy as np
import sys as sys
sys.path.append("..\\..\..\\")
import multiple_regression_random_initialisation as mregress
# Jupyter Notebook will carry over previous variable values, so reset for this next run
del all_regression_out_parameters, regression_parameters

input_csv = "ExampleTwo_SimpleFork_U1_Noise_NetworkValues_butU1deleted.csv"
counter = 0 
while counter < 1:
    regression_parameters = mregress.multi_regress_from_csv_2(input_csv, \
        threshold=0.00001, random = 0, max_iter = 10000, learning_rate = 0.01)

    if "all_regression_out_parameters" in locals():
        all_regression_out_parameters = np.append(all_regression_out_parameters,\
                                             regression_parameters, axis=0)
    else:
        all_regression_out_parameters = regression_parameters
    counter += 1
print("all_regression_parameters: \n", all_regression_out_parameters)
# Out:
# Calling Regression with threshold = 1e-05, random =             0, max_iter = 10000
# random,  0
# setting initial parameters using gradient estimates.
# Calling Regression with threshold = 1e-05, random =             0, max_iter = 10000
# random,  0
# setting initial parameters using gradient estimates.
# Calling Regression with threshold = 1e-05, random =             0, max_iter = 10000
# random,  0
# setting initial parameters using gradient estimates.
# all_regression_parameters:
#  [['  ' '  ']
#  ['dependent' 'X']
#  ['intercept' '8.010683462557404']
#  ['B' '0.3614042366279608']
#  ['Y' '0.6827802453473605']
#  ['r_squared ' array([0.29731998])]
#  ['  ' '  ']
#  ['dependent' 'B']
#  ['intercept' '0.009022748248791857']
#  ['X' '-0.0005685291190102762']
#  ['Y' '3.3329749721837203']
#  ['r_squared ' array([0.99999951])]
#  ['  ' '  ']
#  ['dependent' 'Y']
#  ['intercept' '-0.009021178863272392']
#  ['X' '0.0005741390583757792']
#  ['B' '0.30009823986209383']
#  ['r_squared ' array([0.99999457])]]

# %%
import pandas as pd
import numpy as np
import sys as sys
sys.path.append("..\\..\..\\")
import multiple_regression_random_initialisation as mregress
# delete previously define variables - Jupyter notebook 
# (at least the version on vsstudio keeps them between code instances - that's the point!)
del all_regression_out_parameters, regression_parameters

input_csv = "ExampleTwo_SimpleFork_U1_Noise_NetworkValues_butU1deleted.csv"
counter = 0 
while counter < 1:
    regression_parameters = mregress.multi_regress_from_csv_2(input_csv, \
        threshold=0.00001, random = 0, max_iter = 100000, learning_rate = 0.01)

    if "all_regression_out_parameters" in locals():
        all_regression_out_parameters = np.append(all_regression_out_parameters,\
                                             regression_parameters, axis=0)
    else:
        all_regression_out_parameters = regression_parameters
    counter += 1
print("all_regression_parameters: \n", all_regression_out_parameters)
# Out:
# Calling Regression with threshold = 1e-05, random =             0, max_iter = 100000
# random,  0
# setting initial parameters using gradient estimates.
# Calling Regression with threshold = 1e-05, random =             0, max_iter = 100000
# random,  0
# setting initial parameters using gradient estimates.
# Calling Regression with threshold = 1e-05, random =             0, max_iter = 100000
# random,  0
# setting initial parameters using gradient estimates.
# all_regression_parameters:
#  [['  ' '  ']
#  ['dependent' 'X']
#  ['intercept' '8.010716520650103']
#  ['B' '0.3614013260224386']
#  ['Y' '0.6827793721657318']
#  ['r_squared ' array([0.29731998])]
#  ['  ' '  ']
#  ['dependent' 'B']
#  ['intercept' '0.009022748248791857']
#  ['X' '-0.0005685291190102762']
#  ['Y' '3.3329749721837203']
#  ['r_squared ' array([0.99999951])]
#  ['  ' '  ']
#  ['dependent' 'Y']
#  ['intercept' '-0.009021178863272392']
#  ['X' '0.0005741390583757792']
#  ['B' '0.30009823986209383']
#  ['r_squared ' array([0.99999457])]]

# %%
import pandas as pd
import numpy as np
import sys as sys
sys.path.append("..\\..\..\\")
import multiple_regression_random_initialisation as mregress
# delete previously define variables - Jupyter notebook 
# (at least the version on vsstudio keeps them between code instances - that's the point!)
del all_regression_out_parameters, regression_parameters

input_csv = "ExampleTwo_SimpleFork_U1_Noise_NetworkValues_butU1deleted.csv"
counter = 0 
while counter < 2:
    regression_parameters = mregress.multi_regress_from_csv_2(input_csv, \
        threshold=0.00001, random = 1, max_iter = 1000, learning_rate = 0.01)

    if "all_regression_out_parameters" in locals():
        all_regression_out_parameters = np.append(all_regression_out_parameters,\
                                             regression_parameters, axis=0)
    else:
        all_regression_out_parameters = regression_parameters
    counter += 1
print("all_regression_parameters: \n", all_regression_out_parameters)
# Out:
# Calling Regression with threshold = 1e-05, random =             1, max_iter = 1000
# random,  1
# using pseudo random initial parameter values.
# Calling Regression with threshold = 1e-05, random =             1, max_iter = 1000
# random,  1
# using pseudo random initial parameter values.
# Calling Regression with threshold = 1e-05, random =             1, max_iter = 1000
# random,  1
# using pseudo random initial parameter values.
# Calling Regression with threshold = 1e-05, random =             1, max_iter = 1000
# random,  1
# using pseudo random initial parameter values.
# Calling Regression with threshold = 1e-05, random =             1, max_iter = 1000
# random,  1
# using pseudo random initial parameter values.
# Calling Regression with threshold = 1e-05, random =             1, max_iter = 1000
# random,  1
# using pseudo random initial parameter values.
# all_regression_parameters:
#  [['  ' '  ']
#  ['dependent' 'X']
#  ['intercept' '5.924213780837236']
#  ['B' '0.6333694956373092']
#  ['Y' '0.4436857429128434']
#  ['r_squared ' array([0.24803795])]
#  ['  ' '  ']
#  ['dependent' 'B']
#  ['intercept' '0.2650415015724343']
#  ['X' '-0.01572682959876265']
#  ['Y' '3.317582020438689']
#  ['r_squared ' array([0.99957612])]
#  ['  ' '  ']
#  ['dependent' 'Y']
#  ['intercept' '0.14080497980577447']
#  ['X' '-0.008961316447170124']
#  ['B' '0.2984666458776727']
#  ['r_squared ' array([0.99867778])]
#  ['  ' '  ']
#  ['dependent' 'X']
#  ['intercept' '5.857317272968381']
#  ['B' '0.4950279192870054']
#  ['Y' '0.9262243539980701']
#  ['r_squared ' array([0.24482718])]
#  ['  ' '  ']
#  ['dependent' 'B']
#  ['intercept' '0.49448901784643967']
#  ['X' '-0.030220950115066147']
#  ['Y' '3.308664726257277']
#  ['r_squared ' array([0.99852979])]
#  ['  ' '  ']
#  ['dependent' 'Y']
#  ['intercept' '0.16316321388361732']
#  ['X' '-0.010384271878489565']
#  ['B' '0.29822316663113957']
#  ['r_squared ' array([0.99822453])]]

# %%
import pandas as pd
import numpy as np
import sys as sys
sys.path.append("..\\..\..\\")
import multiple_regression_random_initialisation as mregress
# delete previously define variables - Jupyter notebook 
# (at least the version on vsstudio keeps them between code instances - that's the point!)
del all_regression_out_parameters, regression_parameters

input_csv = "ExampleTwo_SimpleFork_U1_Noise_NetworkValues_butU1deleted.csv"
counter = 0 
while counter < 2:
    regression_parameters = mregress.multi_regress_from_csv_2(input_csv, \
        threshold=0.00001, random = 1, max_iter = 100000, learning_rate = 0.01)

    if "all_regression_out_parameters" in locals():
        all_regression_out_parameters = np.append(all_regression_out_parameters,\
                                             regression_parameters, axis=0)
    else:
        all_regression_out_parameters = regression_parameters
    counter += 1
print("all_regression_parameters: \n", all_regression_out_parameters)
# Out:
# Calling Regression with threshold = 1e-05, random =             1, max_iter = 100000
# random,  1
# using pseudo random initial parameter values.
# Calling Regression with threshold = 1e-05, random =             1, max_iter = 100000
# random,  1
# using pseudo random initial parameter values.
# Calling Regression with threshold = 1e-05, random =             1, max_iter = 100000
# random,  1
# using pseudo random initial parameter values.
# Calling Regression with threshold = 1e-05, random =             1, max_iter = 100000
# random,  1
# using pseudo random initial parameter values.
# Calling Regression with threshold = 1e-05, random =             1, max_iter = 100000
# random,  1
# using pseudo random initial parameter values.
# Calling Regression with threshold = 1e-05, random =             1, max_iter = 100000
# random,  1
# using pseudo random initial parameter values.
# all_regression_parameters:
#  [['  ' '  ']
#  ['dependent' 'X']
#  ['intercept' '8.010716520650103']
#  ['B' '0.4110586133747318']
#  ['Y' '0.5172550809914211']
#  ['r_squared ' array([0.29731998])]
#  ['  ' '  ']
#  ['dependent' 'B']
#  ['intercept' '0.009020785487167452']
#  ['X' '-0.0005684335228944595']
#  ['Y' '3.3329752008149476']
#  ['r_squared ' array([0.99999951])]
#  ['  ' '  ']
#  ['dependent' 'Y']
#  ['intercept' '0.009023048353811543']
#  ['X' '-0.0005742580392266594']
#  ['B' '0.2999017397793148']
#  ['r_squared ' array([0.99999457])]
#  ['  ' '  ']
#  ['dependent' 'X']
#  ['intercept' '8.010716520650103']
#  ['B' '0.54838022213734']
#  ['Y' '0.059516385116060555']
#  ['r_squared ' array([0.29731998])]
#  ['  ' '  ']
#  ['dependent' 'B']
#  ['intercept' '0.00902401099119739']
#  ['X' '-0.0005686367739995705']
#  ['Y' '3.3329750727598153']
#  ['r_squared ' array([0.99999951])]
#  ['  ' '  ']
#  ['dependent' 'Y']
#  ['intercept' '0.009024419312920811']
#  ['X' '-0.000574345291811378']
#  ['B' '0.29990172484968813']
#  ['r_squared ' array([0.99999457])]]
